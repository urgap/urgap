# %% [markdown]
# # UReport
#
# Urgap offers standardized way to investigate meta data, retrieve files and visualize execution via ine class, the `urgap.ureport`

# %%
import urgap
# Out:
# 2024-10-15 11:08:40,418 - __init__.py - 83 - INFO -
#     .__.   .__________.___________.___________.___________.__________.______.      .____.
#      \__\   \_    \    \_     _.   \_       __/     ______/_     _.   \      \      \___\
#               \    \     \    \'   / \_____   ‾‾\   \__    \     \     \      \.____.
#       ____    /     \     \        ‾‾\     \     \          \           \      \  -cf\ .__.
#       \___\   \____________\____\     \__________/______     \_____\     \______      \ \__\
#                                  \_____/                \_____/     \_____/     \_____/
#
#                  ugly      rural      spark     glimpses     any        lazy
#
#   version                : 2.5.17.dev0
#   ursgal home            : /Users/cf322940/.ursgal
#   project_folder         : /Users/cf322940/dev/ursgal2/docs/source/tutorials
#   ursgal config          : /Users/cf322940/.ursgal/ursgal.json
#   scratch disk           : /Users/cf322940/tmp/u_glass_self_divagates_super_cover

# %%
wid = "u_writhing_minister_calculates_near_growth"

# %%
ur = urgap.UReport(wid=wid)

# %% [markdown]
# The UReport uses the UMeta interface to retrieve
#
#   * the history of the execution (run time etc)
#   * the execution traces (which parameter was used in which node with which input files creating which output files)

# %% [markdown]
# The most common way to use a UReport is by using investigating a specific "wid". However, one can also intialize the UReport using e.g. an object_name or node_exe_id.
#
# The node_exe_id is urgap generate output file name consistent of
#
# `<wrapper_name>_<wrapper_version>_<md5_hash_of_parameters_that_trigger_rerun>/<md5_of_input_files>`
#
# One can list all node_exe_ids in the ureport using its attribute

# %%
ur.node_exe_ids
# Out:
# {'test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c'}

# %% [markdown]
# Equaly, since one can initialize the UReport also with node_exe_ids, one can get a list of a wids that executed or skipped a specific node execution.

# %%
ur.wids
# Out:
# {'u_writhing_minister_calculates_near_growth'}

# %%
for node_exe_id, wid in list(ur.uhistory.keys()):
    ut = ur.get_trace(node_exe_id, wid)
    print(node_exe_id)
# Out:
# test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c

# %% [markdown]
# One can get the specific utrace that was created during runtime using:

# %%
ut = ur.get_trace(
    node_exe_id=list(ur.node_exe_ids)[0], 
    wid=wid
)

# %% [markdown]
# See `urgap.UTrace` for more detail about the utrace.
#
# Common operations are for example:

# %%
ut.unode_meta
# Out:
# {'name': 'test_node_v1',
#  'version': '1.0.0',
#  'release_date': '20.02.2020',
#  'engine_type': ('test_engine',),
#  'wrapper_version': {'major': 1, 'minor': 0, 'patch': 0},
#  'platform_independent': True,
#  'engine': {'platform_independent': {'arc_independent': {'exe': 'test_node_v1.py',
#     'zip_md5': 'bfac58dcfd4d8f528b5e59e75b830661'}}},
#  'input_uftypes': {'.test.test_file1': {'min': 1, 'max': -1}},
#  'output_uftypes': {'.test.test_file2': {'min': 1, 'max': -1}},
#  'download_on_demand': False,
#  'utranslation_style': 'ursgal_style_-1',
#  'citation': 'Ursgal team (2021)'}

# %% [markdown]
# One can visualize the execution graph in jupyter by executing:

# %%
ur.draw_execution_dag()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="61fca899-fd22-4e9c-bb46-9faf158e3bd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61fca899-fd22-4e9c-bb46-9faf158e3bd7")) {                    Plotly.newPlot(                        "61fca899-fd22-4e9c-bb46-9faf158e3bd7",                        [{"link":{"arrowlen":15,"source":[1],"target":[0],"value":[1]},"node":{"color":["blue","orange"],"customdata":["\u003cb\u003eUNodeExeID:\u003c\u002fb\u003e test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db\u003cbr\u003e\u003cb\u003eAlias:\u003c\u002fb\u003e 0","\u003cb\u003eUNodeExeID:\u003c\u002fb\u003e \u003c.test.test_file1\u003e\u003cbr\u003e\u003cb\u003eAlias:\u003c\u002fb\u003e 1"],"hovertemplate":"%{customdata}\u003cextra\u003e\u003c\u002fextra\u003e","label":["test_node_v1","\u003c.test.test_file1\u003e"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20},"type":"sankey"}],                        {"hovermode":"closest","margin":{"b":20,"l":5,"r":5,"t":40},"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444," ...

# %% [markdown]
# From this graph one can identify which files were produced by which node. For example, hovering over the simplified dag with alias plot, one can see that each node has an alias - an integer.

# %%
ulist = ur.query_node_outputs_by_aliases(nodes={0: []})

# %%
ulist
# Out:
# UFileList([file:///Users/cf322940/dev/Proteomics/ursgal2_playground/tests/data?md5=58d19f1602ec6ae273c1a15f5671be00&uftype=.test.test_file2#test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c_2_of_3.test.test_file2,
#            file:///Users/cf322940/dev/Proteomics/ursgal2_playground/tests/data?md5=b21d8702d58f558a544b537a1946d357&uftype=.test.test_file2#test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c_3_of_3.test.test_file2,
#            file:///Users/cf322940/dev/Proteomics/ursgal2_playground/tests/data?md5=58d19f1602ec6ae273c1a15f5671be00&uftype=.test.test_file2#test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c_1_of_3.test.test_file2])

# %% [markdown]
# This urgap UFile list has UFiles and those can be can be used to retreive the files as well, e.g.:

# %%
ulist[0].path
# Out:
# 2024-10-15 11:36:19,954 - file.py - 66 - DEBUG - File /Users/cf322940/dev/Proteomics/ursgal2_playground/tests/data/test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c_2_of_3.test.test_file2 does not exist
# PosixPath('/Users/cf322940/tmp/u_glass_self_divagates_super_cover/data/test_node_v1_w1_0d46b87a3f736f3a14bd5a373bbba0db/3ac34db4765f993a029ba0bbc219a15c_2_of_3.test.test_file2')

# %% [markdown]
# Note: If one just want to visualize the execution graph and some run time information, one can equally use the uctl command like:
#
# `uctl dashboard wid u_writhing_minister_calculates_near_growth`
