# %% [markdown]
# # Credential Manager
#
# Urgap provids a standardized interface to interact with different secret stores and present the credentials in a standardized fashion.
#
# As writing this tutorial, Azure Key Vault, Google Cloud Secret Store and classic ENV are surported as secrect stores.
#
# Since we have abstracted the interaction with the secret store in an interfaces (see. urgap.ucredentials.io), other secrets stores can be added with ease.

# %%
import urgap

# %% [markdown]
# Within the urgap home diretory, there is a file called credentials_lookup.json

# %%
import json
from pathlib import Path
uc = json.load(
    open(
        Path(urgap.home / "credentials_lookup.json")
    )
)

# %%
uc
# Out:
# {'description': 'Autogenerated Ursgal Credential lookup',
#  'credentials': [{'description': 'OMIQ Api',
#    'scheme': 'omiq',
#    'host': 'gsk',
#    'user': 'U_OMIQ_USER',
#    'password': 'U_OMIQ_PASSWORD',
#    'secure': True,
#    'secret_store': 'env',
#    'cloud_host_pid': 'gsk.omiq.ai'},
#   {'description': 'gcs using libcloud does not need host yet schema+host is used for internal lookups',
#    'scheme': 'gcs-libcloud',
#    'host': 'gsk-rd-ngs-sbx',
#    'user': 'U_GCS_USER',
#    'password': 'U_GCS_PASSWORD',
#    'secure': True,
#    'secret_store': 'env',
#    'cloud_host_pid': 'gsk-rd-ngs-sbx'},
#   {'description': 'gcs using libcloud does not need host yet schema+host is used for internal lookups',
#    'scheme': 'gcs-libcloud',
#    'host': 'gsk-tech-dso-j2c-eng',
#    'user': 'U_GCS_USER_2',
#    'password': 'U_GCS_PASSWORD_2',
#    'secure': True,
#    'secret_store': 'env',
#    'cloud_host_pid': 'gsk-tech-dso-j2c-eng'},
#   {'description': 'local minio server',
#    'scheme': 'minio',
#    'host': 'localhost:9000',
#    'user': 'U_MINIO_USER',
#    'password': 'U_MINIO_PASSWORD',
#    'secure': False,
#    'secret_store': 'env'},
#   {'description': 'local mongodb',
#    'scheme': 'mongodb',
#    'host': 'localhost:27017',
#    'user': 'U_MONGODB_USER',
#    'password': 'U_MONGODB_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'local ssh',
#    'scheme': 'ssh',
#    'host': 'localhost',
#    'user': 'ENV_VARIABLE_WITH_SSH_USER',
#    'password': 'ENV_VARIABLE_WITH_SSH_KEY',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'github token https raw, here user=password will be foramtted into the query',
#    'scheme': 'https',
#    'host': 'raw.githubusercontent.com',
#    'user': 'U_GITHUB_GSK_USER',
#    'password': 'U_GITHUB_GSK_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'if project_id is defined, it will be used instead of host for GCP secret extraction',
#    'scheme': 'postgresql+pg8000',
#    'host': '10.138.0.5:5432',
#    'user': 'U_GCS_SQL_USER',
#    'password': 'U_GCS_SQL_PASSWORD',
#    'secure': True,
#    'secret_store': 'gcp',
#    'cloud_host_pid': 'gsk-rd-ngs-dev'},
#   {'description': 'if project_id is defined, it will be used instead of host for GCP secret extraction',
#    'scheme': 'postgresql',
#    'host': 'localhost:5432',
#    'user': 'U_POSTGRES_USER',
#    'password': 'U_POSTGRES_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'if project_id is defined, it will be used instead of host for GCP secret extraction',
#    'scheme': 'postgresql',
#    'host': 'us6sdpgs00125.postgres.database.azure.com:5432',
#    'user': 'U_POSTGRES_VXBE00125_USER',
#    'password': 'U_POSTGRES_VXBE00125_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'if project_id is defined, it will be used instead of host for GCP secret extraction',
#    'scheme': 'postgresql',
#    'host': 'us6sdpgs00126.postgres.database.azure.com:5432',
#    'user': 'U_POSTGRES_VXBE00126_USER',
#    'password': 'U_POSTGRES_VXBE00126_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'if project_id is defined, it will be used instead of host for GCP secret extraction',
#    'scheme': 'postgresql',
#    'host': 'us6sdpgs00127.postgres.database.azure.com:5432/us6prdflow03',
#    'user': 'U_POSTGRES_VXBE00127_USER',
#    'password': 'U_POSTGRES_VXBE00127_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'mylabdata interface',
#    'scheme': 'mylabdata',
#    'host': 'mylabdata-files.tst.corpnet2.com',
#    'user': 'U_MYLABDATA_USER',
#    'password': 'U_MYLABDATA_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'mylabdata interface',
#    'scheme': 'mylabdata',
#    'host': 'mylabdata-files.uat.corpnet2.com',
#    'user': 'U_MYLABDATA_USER',
#    'password': 'U_MYLABDATA_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'mylabdata interface',
#    'scheme': 'mylabdata',
#    'host': 'mylabdata-files.corpnet2.com',
#    'user': 'U_MYLABDATA_PROD_USER',
#    'password': 'U_MYLABDATA_PROD_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'smb test interface',
#    'scheme': 'smb',
#    'host': '10.0.20.165:445',
#    'user': 'U_SMB_TEST_USER',
#    'password': 'U_SMB_TEST_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': 'smb GSK - UP - IMTX',
#    'scheme': 'smb',
#    'host': 'us1dsntv048.corpnet2.com',
#    'user': 'U_SMB_GSK_USER',
#    'password': 'U_SMB_GSK_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'},
#   {'description': '>',
#    'scheme': 'azure',
#    'host': 'a-launch-i.gsk.com',
#    'user': 'U_AZURE_UAT_USER',
#    'password': 'U_AZURE_UAT_PASSWORD',
#    'secure': True,
#    'secret_store': 'env'}]}

# %% [markdown]
# This file is used to point the urgap credential manager to the right secret store to extract the credentials. Take for example this entry in the `uc["credentials"]`
# ```
# {
#     'description': 'gcs using libcloud does not need host yet schema+host is used for internal lookups',
#     'scheme': 'gcs-libcloud',
#     'host': 'gsk-rd-ngs-sbx',
#     'user': 'U_GCS_USER',
#     'password': 'U_GCS_PASSWORD',
#     'secure': True,
#     'secret_store': 'env',
#     'cloud_host_pid': 'gsk-rd-ngs-sbx'
# }
# ```

# %% [markdown]
# if a uri or connection string has the schema `gcs-libcloud` and points the the host `gsk-rd-ngs-sbx`, then the secret manager will look into the secret_store `env` and extract the user/login from the variable under `U_GCS_USER` the password from the variable under `U_GCS_PASSWORD`.
#
# urgap will initialze a credential manager under
# `urgap.instances.ucredential_manager` during init.
#
# We can extract the credentials using the the methods `.extract_credentials`, `.get_password` or `.get_user`.
#
# We can also supply more credentials dynamically using the `.add_credentials` methods. For example:

# %%
um = urgap.UCredentialManager()
um.add_credentials(
    [
        {
            'base_url': 'dog://town',
            'description': 'Demo1',
            'scheme': 'dog',
            'host': 'town',
            'user': 'U_DOG_USER',
            'password': 'U_DOG_PASSWORD',
            'secure': True,
            'secret_store': 'env',
            'cloud_host_pid': 'gsk-rd-ngs-sbx'
        }
    ]
)

# %% [markdown]
# Let set those env variables now.

# %%
import os
os.environ["U_DOG_USER"] = "d0g-name"
os.environ["U_DOG_PASSWORD"] = "d0g-password"

# %%
um.get_password("dog://town")
# Out:
# 'd0g-password'

# %%
um.extract_credentials("dog://town")
# Out:
# {'user': 'd0g-name', 'password': 'd0g-password'}

# %%
urgap.ucredentials.io.gcp.IOGCPCreds(secret_id="sasa", version_id="L@!#!", project_id="ASda")
